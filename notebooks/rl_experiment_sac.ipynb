# %% [markdown]
# # Ray RLlib 강화학습 실험
#
# 이 노트북은 Ray RLlib을 사용한 강화학습 연구의 기본 템플릿입니다.

# %%
# 필수 라이브러리 import
import ray
from ray.rllib.algorithms.sac import SACConfig
from ray.rllib.algorithms.sac.torch.default_sac_torch_rl_module import DefaultSACTorchRLModule
from ray.rllib.connectors.env_to_module import EnvToModulePipeline
from ray.rllib.connectors.module_to_env import ModuleToEnvPipeline
from ray.rllib.core.columns import Columns
from ray.rllib.core.rl_module.rl_module import RLModule, RLModuleSpec
from ray.rllib.core.rl_module.default_model_config import DefaultModelConfig
from ray.rllib.env.single_agent_episode import SingleAgentEpisode
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
import os
import sys
import torch

PROJECT_ROOT = os.path.dirname(os.path.dirname(os.path.abspath("__file__")))
sys.path.append(PROJECT_ROOT)

# 패키지 Util 함수
from utils.utils import * 

print("라이브러리 import 완료")
# Out:
# 라이브러리 import 완료

# %% [markdown]
# ## 1. Ray 초기화

# %%
# Ray 초기화
# 로컬 모드로 실행 (디버깅용)
# ray.init(local_mode=True)

# 일반 모드로 실행 (실험용)
ray.init(ignore_reinit_error=True)

print(f"Ray 클러스터 정보: {ray.cluster_resources()}")
# Out:
# 2026-01-28 21:56:38,163	INFO worker.py:2007 -- Started a local Ray instance.
# Ray 클러스터 정보: {'GPU': 1.0, 'object_store_memory': 78615070310.0, 'accelerator_type:G': 1.0, 'memory': 183435164058.0, 'node:__internal_head__': 1.0, 'node:10.254.233.114': 1.0, 'CPU': 32.0}
# /home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/_private/worker.py:2046: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(

# %% [markdown]
# ## 2. 환경 설정
#
# **참고**: 실제 환경은 별도 프로젝트로 관리되므로, 여기서는 예시로 Gymnasium 환경을 사용합니다.
# 실제 환경을 사용할 때는 해당 환경의 import 경로를 수정하세요.

# %%
ENV_NAME = "horcrux_env/plane-v0"

# 환경 정보 확인
import gymnasium as gym
import horcrux_env
from horcrux_env.envs import PlaneJoyDirWorld

env = gym.make(ENV_NAME)
print(f"환경: {ENV_NAME}")
print(f"관찰 공간: {env.observation_space}")
print(f"행동 공간: {env.action_space}")

ENV_OBS_SPACE = env.observation_space
ENV_ACTION_SPACE = env.action_space


env.close()
# Out:
# 환경: horcrux_env/plane-v0
# 관찰 공간: Box(-inf, inf, (97,), float32)
# 행동 공간: Box(0.0, 2.7, (14,), float32)

# %%
ENV_CONFIG = {
    "forward_reward_weight": 175.0,
    "rotation_reward_weight": 100.0,
    "unhealthy_max_steps": 150.0,
    "healthy_reward": 3.0,
    "healthy_roll_range": (-40,40),
    "terminating_roll_range": (-80,80),
    "rotation_norm_cost_weight": 7.5,
    "termination_reward": 0,
    "gait_params": (30, 30, 40, 40, 0, 1),
    "use_friction_chg": True,
    "joy_input_random": False,
    "use_imu_window": True,
    "use_vels_window": True,
    "ctrl_cost_weight": 0.07,
}

RENDER_ENV_CONFIG = ENV_CONFIG.copy()
RENDER_ENV_CONFIG['render_mode'] = 'rgb_array'
RENDER_ENV_CONFIG['render_camera_name'] = 'ceiling'

# env = gym.make(ENV_NAME, **RENDER_ENV_CONFIG)

# from ray.tune.registry import register_env
# register_env(ENV_NAME, lambda config: PlaneJoyDirWorld( forward_reward_weight=ENV_CONFIG["forward_reward_weight"], 
#                                                      rotation_reward_weight=ENV_CONFIG["rotation_reward_weight"], 
#                                                      unhealthy_max_steps=ENV_CONFIG["unhealthy_max_steps"],
#                                                      healthy_reward=ENV_CONFIG["healthy_reward"], 
#                                                      healthy_roll_range=ENV_CONFIG["healthy_roll_range"],
#                                                      terminating_roll_range=ENV_CONFIG["terminating_roll_range"],
#                                                      rotation_norm_cost_weight=ENV_CONFIG["rotation_norm_cost_weight"],
#                                                      termination_reward=ENV_CONFIG["termination_reward"],
#                                                      gait_params=ENV_CONFIG["gait_params"],
#                                                      use_friction_chg=ENV_CONFIG["use_friction_chg"],
#                                                      joy_input_random=ENV_CONFIG["joy_input_random"],
#                                                      use_imu_window=ENV_CONFIG["use_imu_window"],
#                                                      ctrl_cost_weight=ENV_CONFIG["ctrl_cost_weight"],
#                                                    )
#             )

# %% [markdown]
# ## 3. RLlib 알고리즘 설정

# %%
# PPO 알고리즘 설정 (다른 알고리즘으로 변경 가능: DQN, A3C, SAC 등)
config = (
    SACConfig()
    .environment(env=ENV_NAME)
    .training(
        gamma=0.92,
        # model={
        #     "fcnet_hiddens": [512, 512, 512, 512, 512, 512, 128],
        #     "fcnet_activation": "tanh",
        #     "vf_share_layers": False,
        # },
        # q_model_config={
        #     "fcnet_hiddens": [512, 512, 512, 512, 512, 512, 128],
        #     "fcnet_activation": "tanh",
        #     "vf_share_layers": False,
        # },
        # policy_model_config={
        #     "fcnet_hiddens": [512, 512, 512, 512, 512, 512, 128],
        #     "fcnet_activation": "tanh",
        #     "vf_share_layers": False,
        # },
        # train_batch_size=16384,
        # train_batch_size_per_learner=8192,
        optimization_config={
            "actor_learning_rate": 3e-5,
            "critic_learning_rate": 3e-5,
            "entropy_learning_rate": 3e-5,
        },
        n_step=5,
        # target_entropy="auto",
        # replay_buffer_config={
        #     "capacity": 5000000,
        # },
    )
    .resources(num_gpus=1)  # GPU 사용 시 1로 변경
    .framework("torch")  # "tf2" 또는 "torch"
    .env_runners(
        num_env_runners=8,
    )
    .learners(
        num_learners=1,
        num_gpus_per_learner=1,
    )
    # .rl_module(
    #     # rl_module_spec= RLModuleSpec(
    #     #     module_class=DefaultSACTorchRLModule,
    #     #     observation_space=ENV_OBS_SPACE,
    #     #     action_space=ENV_ACTION_SPACE,
    #     # ),
    #     model_config=DefaultModelConfig(
    #         fcnet_hiddens=[512, 512, 512, 512, 512, 512, 128],
    #         fcnet_activation="tanh",
    #         vf_share_layers=False,
    #     ),
    # )
)

print("알고리즘 설정 완료")
print(config)
# Out:
# 알고리즘 설정 완료
# <ray.rllib.algorithms.sac.sac.SACConfig object at 0x7e7418108110>

# %% [markdown]
# ## 4. 알고리즘 인스턴스 생성 및 학습

# %%
# 알고리즘 인스턴스 생성
algo = config.build_algo()

print("알고리즘 인스턴스 생성 완료")
# Out:
# 2026-01-28 21:56:48,665	WARNING algorithm_config.py:5118 -- You are running SAC on the new API stack! This is the new default behavior for this algorithm. If you don't want to use the new API stack, set `config.api_stack(enable_rl_module_and_learner=False,enable_env_runner_and_connector_v2=False)`. For a detailed migration guide, see here: https://docs.ray.io/en/master/rllib/new-api-stack-migration-guide.html
# 2026-01-28 21:56:48,666	WARNING sac.py:491 -- You are running SAC on the new API stack! This is the new default behavior for this algorithm. If you don't want to use the new API stack, set `config.api_stack(enable_rl_module_and_learner=False, enable_env_runner_and_connector_v2=False)`. For a detailed migration guide, see here: https://docs.ray.io/en/master/rllib/new-api-stack-migration-guide.html
# /home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/algorithms/algorithm.py:527: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# [2026-01-28 21:56:48,806 E 61940 61940] core_worker.cc:2223: Actor with class name: 'SingleAgentEnvRunner' and ID: '77114ae351757c9872562ec901000000' has constructor arguments in the object store and max_restarts > 0. If the arguments in the object store go out of scope or are lost, the actor restart will fail. See https://github.com/ray-project/ray/issues/53727 for more details.
# (SingleAgentEnvRunner pid=62429) Exception raised in creation task: The actor died because of an error raised in its creation task, ray::SingleAgentEnvRunner.__init__() (pid=62429, ip=10.254.233.114, actor_id=77114ae351757c9872562ec901000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x721e0d34c8d0>)
# (SingleAgentEnvRunner pid=62429)   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 872, in make_vec
# (SingleAgentEnvRunner pid=62429)     env_spec = _find_spec(id)
# (SingleAgentEnvRunner pid=62429)                ^^^^^^^^^^^^^^
# (SingleAgentEnvRunner pid=62429)   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 533, in _find_spec
# (SingleAgentEnvRunner pid=62429)     _check_version_exists(ns, name, version)
# (SingleAgentEnvRunner pid=62429)   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 399, in _check_version_exists
# (SingleAgentEnvRunner pid=62429)     _check_name_exists(ns, name)
# (SingleAgentEnvRunner pid=62429)   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 362, in _check_name_exists
# (SingleAgentEnvRunner pid=62429)     _check_namespace_exists(ns)
# (SingleAgentEnvRunner pid=62429)   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 356, in _check_namespace_exists
# (SingleAgentEnvRunner pid=62429)     raise error.NamespaceNotFound(f"Namespace {ns} not found. {suggestion_msg}")
# (SingleAgentEnvRunner pid=62429) gymnasium.error.NamespaceNotFound: Namespace horcrux_env not found. Have you installed the proper package for horcrux_env?
# (SingleAgentEnvRunner pid=62429)
# (SingleAgentEnvRunner pid=62429) The above exception was the direct cause of the following exception:
# (SingleAgentEnvRunner pid=62429)
# (SingleAgentEnvRunner pid=62429) ray::SingleAgentEnvRunner.__init__() (pid=62429, ip=10.254.233.114, actor_id=77114ae351757c9872562ec901000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x721e0d34c8d0>)
# (SingleAgentEnvRunner pid=62429)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (SingleAgentEnvRunner pid=62429)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (SingleAgentEnvRunner pid=62429)   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 103, in __init__
# (SingleAgentEnvRunner pid=62429)     self.make_env()
# (SingleAgentEnvRunner pid=62429)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (SingleAgentEnvRunner pid=62429)   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 707, in make_env
# (SingleAgentEnvRunner pid=62429)     raise EnvError(
# (SingleAgentEnvRunner pid=62429) ray.rllib.utils.error.EnvError: The env string you provided ('horcrux_env/plane-v0') is:
# (SingleAgentEnvRunner pid=62429) a) Not a supported or an installed environment.
# (SingleAgentEnvRunner pid=62429) b) Not a tune-registered environment creator.
# (SingleAgentEnvRunner pid=62429) c) Not a valid env class string.
# (SingleAgentEnvRunner pid=62429)
# (SingleAgentEnvRunner pid=62429) Try one of the following:
# (SingleAgentEnvRunner pid=62429) a) For Atari support: `pip install gymnasium[atari]` and prefix the environment name with `ale_py:`, for example, `"ale_py:ALE/Pong-v5"`.
# (SingleAgentEnvRunner pid=62429) b) To register your custom env, do `from ray import tune; tune.register_env('[name]', lambda cfg: [return env obj from here using cfg])`.
# (SingleAgentEnvRunner pid=62429)    Then in your config, do `config.environment(env='[name]').
# (SingleAgentEnvRunner pid=62429) c) Make sure you provide a fully qualified classpath, e.g.:
# (SingleAgentEnvRunner pid=62429)    `ray.rllib.examples.envs.classes.repeat_after_me_env.RepeatAfterMeEnv`
# (SingleAgentEnvRunner pid=62432)
# (SingleAgentEnvRunner pid=62432)
# (SingleAgentEnvRunner pid=62432)
# (SingleAgentEnvRunner pid=62449)
# (SingleAgentEnvRunner pid=62449)
# (SingleAgentEnvRunner pid=62449)
# (SingleAgentEnvRunner pid=62435)
# (SingleAgentEnvRunner pid=62435)
# (SingleAgentEnvRunner pid=62435)
# (SingleAgentEnvRunner pid=62436)
# (SingleAgentEnvRunner pid=62436)
# (SingleAgentEnvRunner pid=62436)
# 2026-01-28 21:56:50,568	ERROR actor_manager.py:973 -- Ray error (The actor died because of an error raised in its creation task, ray::SingleAgentEnvRunner.__init__() (pid=62429, ip=10.254.233.114, actor_id=77114ae351757c9872562ec901000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x721e0d34c8d0>)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 872, in make_vec
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 533, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 399, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 362, in _check_name_exists
#     _check_namespace_exists(ns)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 356, in _check_namespace_exists
#     raise error.NamespaceNotFound(f"Namespace {ns} not found. {suggestion_msg}")
# gymnasium.error.NamespaceNotFound: Namespace horcrux_env not found. Have you installed the proper package for horcrux_env?
#
# The above exception was the direct cause of the following exception:
#
# ray::SingleAgentEnvRunner.__init__() (pid=62429, ip=10.254.233.114, actor_id=77114ae351757c9872562ec901000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x721e0d34c8d0>)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 103, in __init__
#     self.make_env()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 707, in make_env
#     raise EnvError(
# ray.rllib.utils.error.EnvError: The env string you provided ('horcrux_env/plane-v0') is:
# a) Not a supported or an installed environment.
# b) Not a tune-registered environment creator.
# c) Not a valid env class string.
#
# Try one of the following:
# a) For Atari support: `pip install gymnasium[atari]` and prefix the environment name with `ale_py:`, for example, `"ale_py:ALE/Pong-v5"`.
# b) To register your custom env, do `from ray import tune; tune.register_env('[name]', lambda cfg: [return env obj from here using cfg])`.
#    Then in your config, do `config.environment(env='[name]').
# c) Make sure you provide a fully qualified classpath, e.g.:
#    `ray.rllib.examples.envs.classes.repeat_after_me_env.RepeatAfterMeEnv`), taking actor 1 out of service.
# 2026-01-28 21:56:50,568	ERROR actor_manager.py:973 -- Ray error (The actor died because of an error raised in its creation task, ray::SingleAgentEnvRunner.__init__() (pid=62435, ip=10.254.233.114, actor_id=f0801c92fe638bf9c2555b2f01000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x7ce5c931ffd0>)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 872, in make_vec
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 533, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 399, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 362, in _check_name_exists
#     _check_namespace_exists(ns)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 356, in _check_namespace_exists
#     raise error.NamespaceNotFound(f"Namespace {ns} not found. {suggestion_msg}")
# gymnasium.error.NamespaceNotFound: Namespace horcrux_env not found. Have you installed the proper package for horcrux_env?
#
# The above exception was the direct cause of the following exception:
#
# ray::SingleAgentEnvRunner.__init__() (pid=62435, ip=10.254.233.114, actor_id=f0801c92fe638bf9c2555b2f01000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x7ce5c931ffd0>)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 103, in __init__
#     self.make_env()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 707, in make_env
#     raise EnvError(
# ray.rllib.utils.error.EnvError: The env string you provided ('horcrux_env/plane-v0') is:
# a) Not a supported or an installed environment.
# b) Not a tune-registered environment creator.
# c) Not a valid env class string.
#
# Try one of the following:
# a) For Atari support: `pip install gymnasium[atari]` and prefix the environment name with `ale_py:`, for example, `"ale_py:ALE/Pong-v5"`.
# b) To register your custom env, do `from ray import tune; tune.register_env('[name]', lambda cfg: [return env obj from here using cfg])`.
#    Then in your config, do `config.environment(env='[name]').
# c) Make sure you provide a fully qualified classpath, e.g.:
#    `ray.rllib.examples.envs.classes.repeat_after_me_env.RepeatAfterMeEnv`), taking actor 2 out of service.
# 2026-01-28 21:56:50,568	ERROR actor_manager.py:973 -- Ray error (The actor died because of an error raised in its creation task, ray::SingleAgentEnvRunner.__init__() (pid=62432, ip=10.254.233.114, actor_id=258dadeefd2d545a84fc866f01000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x71c1ac019950>)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 872, in make_vec
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 533, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 399, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 362, in _check_name_exists
#     _check_namespace_exists(ns)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 356, in _check_namespace_exists
#     raise error.NamespaceNotFound(f"Namespace {ns} not found. {suggestion_msg}")
# gymnasium.error.NamespaceNotFound: Namespace horcrux_env not found. Have you installed the proper package for horcrux_env?
#
# The above exception was the direct cause of the following exception:
#
# ray::SingleAgentEnvRunner.__init__() (pid=62432, ip=10.254.233.114, actor_id=258dadeefd2d545a84fc866f01000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x71c1ac019950>)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 103, in __init__
#     self.make_env()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 707, in make_env
#     raise EnvError(
# ray.rllib.utils.error.EnvError: The env string you provided ('horcrux_env/plane-v0') is:
# a) Not a supported or an installed environment.
# b) Not a tune-registered environment creator.
# c) Not a valid env class string.
#
# Try one of the following:
# a) For Atari support: `pip install gymnasium[atari]` and prefix the environment name with `ale_py:`, for example, `"ale_py:ALE/Pong-v5"`.
# b) To register your custom env, do `from ray import tune; tune.register_env('[name]', lambda cfg: [return env obj from here using cfg])`.
#    Then in your config, do `config.environment(env='[name]').
# c) Make sure you provide a fully qualified classpath, e.g.:
#    `ray.rllib.examples.envs.classes.repeat_after_me_env.RepeatAfterMeEnv`), taking actor 3 out of service.
# 2026-01-28 21:56:50,569	ERROR actor_manager.py:973 -- Ray error (The actor died because of an error raised in its creation task, ray::SingleAgentEnvRunner.__init__() (pid=62449, ip=10.254.233.114, actor_id=ffe6eaf6eb9b6d8103818c0c01000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x737f87f9b950>)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 872, in make_vec
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 533, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 399, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 362, in _check_name_exists
#     _check_namespace_exists(ns)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 356, in _check_namespace_exists
#     raise error.NamespaceNotFound(f"Namespace {ns} not found. {suggestion_msg}")
# gymnasium.error.NamespaceNotFound: Namespace horcrux_env not found. Have you installed the proper package for horcrux_env?
#
# The above exception was the direct cause of the following exception:
#
# ray::SingleAgentEnvRunner.__init__() (pid=62449, ip=10.254.233.114, actor_id=ffe6eaf6eb9b6d8103818c0c01000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x737f87f9b950>)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 103, in __init__
#     self.make_env()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 707, in make_env
#     raise EnvError(
# ray.rllib.utils.error.EnvError: The env string you provided ('horcrux_env/plane-v0') is:
# a) Not a supported or an installed environment.
# b) Not a tune-registered environment creator.
# c) Not a valid env class string.
#
# Try one of the following:
# a) For Atari support: `pip install gymnasium[atari]` and prefix the environment name with `ale_py:`, for example, `"ale_py:ALE/Pong-v5"`.
# b) To register your custom env, do `from ray import tune; tune.register_env('[name]', lambda cfg: [return env obj from here using cfg])`.
#    Then in your config, do `config.environment(env='[name]').
# c) Make sure you provide a fully qualified classpath, e.g.:
#    `ray.rllib.examples.envs.classes.repeat_after_me_env.RepeatAfterMeEnv`), taking actor 4 out of service.
# 2026-01-28 21:56:50,569	ERROR actor_manager.py:973 -- Ray error (The actor died because of an error raised in its creation task, ray::SingleAgentEnvRunner.__init__() (pid=62431, ip=10.254.233.114, actor_id=bd38b64249b89410b40ab2fc01000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x766dd2ae3910>)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 872, in make_vec
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 533, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 399, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 362, in _check_name_exists
#     _check_namespace_exists(ns)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 356, in _check_namespace_exists
#     raise error.NamespaceNotFound(f"Namespace {ns} not found. {suggestion_msg}")
# gymnasium.error.NamespaceNotFound: Namespace horcrux_env not found. Have you installed the proper package for horcrux_env?
#
# The above exception was the direct cause of the following exception:
#
# ray::SingleAgentEnvRunner.__init__() (pid=62431, ip=10.254.233.114, actor_id=bd38b64249b89410b40ab2fc01000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x766dd2ae3910>)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 103, in __init__
#     self.make_env()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 707, in make_env
#     raise EnvError(
# ray.rllib.utils.error.EnvError: The env string you provided ('horcrux_env/plane-v0') is:
# a) Not a supported or an installed environment.
# b) Not a tune-registered environment creator.
# c) Not a valid env class string.
#
# Try one of the following:
# a) For Atari support: `pip install gymnasium[atari]` and prefix the environment name with `ale_py:`, for example, `"ale_py:ALE/Pong-v5"`.
# b) To register your custom env, do `from ray import tune; tune.register_env('[name]', lambda cfg: [return env obj from here using cfg])`.
#    Then in your config, do `config.environment(env='[name]').
# c) Make sure you provide a fully qualified classpath, e.g.:
#    `ray.rllib.examples.envs.classes.repeat_after_me_env.RepeatAfterMeEnv`), taking actor 5 out of service.
# 2026-01-28 21:56:50,569	ERROR actor_manager.py:973 -- Ray error (The actor died because of an error raised in its creation task, ray::SingleAgentEnvRunner.__init__() (pid=62436, ip=10.254.233.114, actor_id=76e0b793ce26d3f3bcb30cd501000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x7e7c579a48d0>)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 872, in make_vec
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 533, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 399, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 362, in _check_name_exists
#     _check_namespace_exists(ns)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 356, in _check_namespace_exists
#     raise error.NamespaceNotFound(f"Namespace {ns} not found. {suggestion_msg}")
# gymnasium.error.NamespaceNotFound: Namespace horcrux_env not found. Have you installed the proper package for horcrux_env?
#
# The above exception was the direct cause of the following exception:
#
# ray::SingleAgentEnvRunner.__init__() (pid=62436, ip=10.254.233.114, actor_id=76e0b793ce26d3f3bcb30cd501000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x7e7c579a48d0>)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 103, in __init__
#     self.make_env()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 707, in make_env
#     raise EnvError(
# ray.rllib.utils.error.EnvError: The env string you provided ('horcrux_env/plane-v0') is:
# a) Not a supported or an installed environment.
# b) Not a tune-registered environment creator.
# c) Not a valid env class string.
#
# Try one of the following:
# a) For Atari support: `pip install gymnasium[atari]` and prefix the environment name with `ale_py:`, for example, `"ale_py:ALE/Pong-v5"`.
# b) To register your custom env, do `from ray import tune; tune.register_env('[name]', lambda cfg: [return env obj from here using cfg])`.
#    Then in your config, do `config.environment(env='[name]').
# c) Make sure you provide a fully qualified classpath, e.g.:
#    `ray.rllib.examples.envs.classes.repeat_after_me_env.RepeatAfterMeEnv`), taking actor 6 out of service.
# 2026-01-28 21:56:50,569	ERROR actor_manager.py:973 -- Ray error (The actor died because of an error raised in its creation task, ray::SingleAgentEnvRunner.__init__() (pid=62444, ip=10.254.233.114, actor_id=a84c07a70b3a0e0e13f33ef301000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x777132f5c8d0>)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 872, in make_vec
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 533, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 399, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 362, in _check_name_exists
#     _check_namespace_exists(ns)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 356, in _check_namespace_exists
#     raise error.NamespaceNotFound(f"Namespace {ns} not found. {suggestion_msg}")
# gymnasium.error.NamespaceNotFound: Namespace horcrux_env not found. Have you installed the proper package for horcrux_env?
#
# The above exception was the direct cause of the following exception:
#
# ray::SingleAgentEnvRunner.__init__() (pid=62444, ip=10.254.233.114, actor_id=a84c07a70b3a0e0e13f33ef301000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x777132f5c8d0>)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 103, in __init__
#     self.make_env()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 707, in make_env
#     raise EnvError(
# ray.rllib.utils.error.EnvError: The env string you provided ('horcrux_env/plane-v0') is:
# a) Not a supported or an installed environment.
# b) Not a tune-registered environment creator.
# c) Not a valid env class string.
#
# Try one of the following:
# a) For Atari support: `pip install gymnasium[atari]` and prefix the environment name with `ale_py:`, for example, `"ale_py:ALE/Pong-v5"`.
# b) To register your custom env, do `from ray import tune; tune.register_env('[name]', lambda cfg: [return env obj from here using cfg])`.
#    Then in your config, do `config.environment(env='[name]').
# c) Make sure you provide a fully qualified classpath, e.g.:
#    `ray.rllib.examples.envs.classes.repeat_after_me_env.RepeatAfterMeEnv`), taking actor 7 out of service.
# 2026-01-28 21:56:50,570	ERROR actor_manager.py:973 -- Ray error (The actor died because of an error raised in its creation task, ray::SingleAgentEnvRunner.__init__() (pid=62448, ip=10.254.233.114, actor_id=8cab7ac8a7012a93c74017bc01000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x74a803f1fd50>)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 872, in make_vec
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 533, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 399, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 362, in _check_name_exists
#     _check_namespace_exists(ns)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 356, in _check_namespace_exists
#     raise error.NamespaceNotFound(f"Namespace {ns} not found. {suggestion_msg}")
# gymnasium.error.NamespaceNotFound: Namespace horcrux_env not found. Have you installed the proper package for horcrux_env?
#
# The above exception was the direct cause of the following exception:
#
# ray::SingleAgentEnvRunner.__init__() (pid=62448, ip=10.254.233.114, actor_id=8cab7ac8a7012a93c74017bc01000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x74a803f1fd50>)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 103, in __init__
#     self.make_env()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 707, in make_env
#     raise EnvError(
# ray.rllib.utils.error.EnvError: The env string you provided ('horcrux_env/plane-v0') is:
# a) Not a supported or an installed environment.
# b) Not a tune-registered environment creator.
# c) Not a valid env class string.
#
# Try one of the following:
# a) For Atari support: `pip install gymnasium[atari]` and prefix the environment name with `ale_py:`, for example, `"ale_py:ALE/Pong-v5"`.
# b) To register your custom env, do `from ray import tune; tune.register_env('[name]', lambda cfg: [return env obj from here using cfg])`.
#    Then in your config, do `config.environment(env='[name]').
# c) Make sure you provide a fully qualified classpath, e.g.:
#    `ray.rllib.examples.envs.classes.repeat_after_me_env.RepeatAfterMeEnv`), taking actor 8 out of service.
# 2026-01-28 21:56:50,570	ERROR env_runner_group.py:791 -- Validation of EnvRunner failed! Error=The actor died because of an error raised in its creation task, ray::SingleAgentEnvRunner.__init__() (pid=62429, ip=10.254.233.114, actor_id=77114ae351757c9872562ec901000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x721e0d34c8d0>)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 872, in make_vec
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 533, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 399, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 362, in _check_name_exists
#     _check_namespace_exists(ns)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 356, in _check_namespace_exists
#     raise error.NamespaceNotFound(f"Namespace {ns} not found. {suggestion_msg}")
# gymnasium.error.NamespaceNotFound: Namespace horcrux_env not found. Have you installed the proper package for horcrux_env?
#
# The above exception was the direct cause of the following exception:
#
# ray::SingleAgentEnvRunner.__init__() (pid=62429, ip=10.254.233.114, actor_id=77114ae351757c9872562ec901000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x721e0d34c8d0>)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 103, in __init__
#     self.make_env()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 707, in make_env
#     raise EnvError(
# ray.rllib.utils.error.EnvError: The env string you provided ('horcrux_env/plane-v0') is:
# a) Not a supported or an installed environment.
# b) Not a tune-registered environment creator.
# c) Not a valid env class string.
#
# Try one of the following:
# a) For Atari support: `pip install gymnasium[atari]` and prefix the environment name with `ale_py:`, for example, `"ale_py:ALE/Pong-v5"`.
# b) To register your custom env, do `from ray import tune; tune.register_env('[name]', lambda cfg: [return env obj from here using cfg])`.
#    Then in your config, do `config.environment(env='[name]').
# c) Make sure you provide a fully qualified classpath, e.g.:
#    `ray.rllib.examples.envs.classes.repeat_after_me_env.RepeatAfterMeEnv`
# 2026-01-28 21:56:50,570	ERROR env_runner_group.py:791 -- Validation of EnvRunner failed! Error=The actor died because of an error raised in its creation task, ray::SingleAgentEnvRunner.__init__() (pid=62435, ip=10.254.233.114, actor_id=f0801c92fe638bf9c2555b2f01000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x7ce5c931ffd0>)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 872, in make_vec
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 533, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 399, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 362, in _check_name_exists
#     _check_namespace_exists(ns)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 356, in _check_namespace_exists
#     raise error.NamespaceNotFound(f"Namespace {ns} not found. {suggestion_msg}")
# gymnasium.error.NamespaceNotFound: Namespace horcrux_env not found. Have you installed the proper package for horcrux_env?
#
# The above exception was the direct cause of the following exception:
#
# ray::SingleAgentEnvRunner.__init__() (pid=62435, ip=10.254.233.114, actor_id=f0801c92fe638bf9c2555b2f01000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x7ce5c931ffd0>)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 103, in __init__
#     self.make_env()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 707, in make_env
#     raise EnvError(
# ray.rllib.utils.error.EnvError: The env string you provided ('horcrux_env/plane-v0') is:
# a) Not a supported or an installed environment.
# b) Not a tune-registered environment creator.
# c) Not a valid env class string.
#
# Try one of the following:
# a) For Atari support: `pip install gymnasium[atari]` and prefix the environment name with `ale_py:`, for example, `"ale_py:ALE/Pong-v5"`.
# b) To register your custom env, do `from ray import tune; tune.register_env('[name]', lambda cfg: [return env obj from here using cfg])`.
#    Then in your config, do `config.environment(env='[name]').
# c) Make sure you provide a fully qualified classpath, e.g.:
#    `ray.rllib.examples.envs.classes.repeat_after_me_env.RepeatAfterMeEnv`
# 2026-01-28 21:56:50,570	ERROR env_runner_group.py:791 -- Validation of EnvRunner failed! Error=The actor died because of an error raised in its creation task, ray::SingleAgentEnvRunner.__init__() (pid=62432, ip=10.254.233.114, actor_id=258dadeefd2d545a84fc866f01000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x71c1ac019950>)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 872, in make_vec
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 533, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 399, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 362, in _check_name_exists
#     _check_namespace_exists(ns)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 356, in _check_namespace_exists
#     raise error.NamespaceNotFound(f"Namespace {ns} not found. {suggestion_msg}")
# gymnasium.error.NamespaceNotFound: Namespace horcrux_env not found. Have you installed the proper package for horcrux_env?
#
# The above exception was the direct cause of the following exception:
#
# ray::SingleAgentEnvRunner.__init__() (pid=62432, ip=10.254.233.114, actor_id=258dadeefd2d545a84fc866f01000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x71c1ac019950>)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 103, in __init__
#     self.make_env()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 707, in make_env
#     raise EnvError(
# ray.rllib.utils.error.EnvError: The env string you provided ('horcrux_env/plane-v0') is:
# a) Not a supported or an installed environment.
# b) Not a tune-registered environment creator.
# c) Not a valid env class string.
#
# Try one of the following:
# a) For Atari support: `pip install gymnasium[atari]` and prefix the environment name with `ale_py:`, for example, `"ale_py:ALE/Pong-v5"`.
# b) To register your custom env, do `from ray import tune; tune.register_env('[name]', lambda cfg: [return env obj from here using cfg])`.
#    Then in your config, do `config.environment(env='[name]').
# c) Make sure you provide a fully qualified classpath, e.g.:
#    `ray.rllib.examples.envs.classes.repeat_after_me_env.RepeatAfterMeEnv`
# 2026-01-28 21:56:50,570	ERROR env_runner_group.py:791 -- Validation of EnvRunner failed! Error=The actor died because of an error raised in its creation task, ray::SingleAgentEnvRunner.__init__() (pid=62449, ip=10.254.233.114, actor_id=ffe6eaf6eb9b6d8103818c0c01000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x737f87f9b950>)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 872, in make_vec
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 533, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 399, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 362, in _check_name_exists
#     _check_namespace_exists(ns)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 356, in _check_namespace_exists
#     raise error.NamespaceNotFound(f"Namespace {ns} not found. {suggestion_msg}")
# gymnasium.error.NamespaceNotFound: Namespace horcrux_env not found. Have you installed the proper package for horcrux_env?
#
# The above exception was the direct cause of the following exception:
#
# ray::SingleAgentEnvRunner.__init__() (pid=62449, ip=10.254.233.114, actor_id=ffe6eaf6eb9b6d8103818c0c01000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x737f87f9b950>)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 103, in __init__
#     self.make_env()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 707, in make_env
#     raise EnvError(
# ray.rllib.utils.error.EnvError: The env string you provided ('horcrux_env/plane-v0') is:
# a) Not a supported or an installed environment.
# b) Not a tune-registered environment creator.
# c) Not a valid env class string.
#
# Try one of the following:
# a) For Atari support: `pip install gymnasium[atari]` and prefix the environment name with `ale_py:`, for example, `"ale_py:ALE/Pong-v5"`.
# b) To register your custom env, do `from ray import tune; tune.register_env('[name]', lambda cfg: [return env obj from here using cfg])`.
#    Then in your config, do `config.environment(env='[name]').
# c) Make sure you provide a fully qualified classpath, e.g.:
#    `ray.rllib.examples.envs.classes.repeat_after_me_env.RepeatAfterMeEnv`
# 2026-01-28 21:56:50,570	ERROR env_runner_group.py:791 -- Validation of EnvRunner failed! Error=The actor died because of an error raised in its creation task, ray::SingleAgentEnvRunner.__init__() (pid=62431, ip=10.254.233.114, actor_id=bd38b64249b89410b40ab2fc01000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x766dd2ae3910>)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 872, in make_vec
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 533, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 399, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 362, in _check_name_exists
#     _check_namespace_exists(ns)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 356, in _check_namespace_exists
#     raise error.NamespaceNotFound(f"Namespace {ns} not found. {suggestion_msg}")
# gymnasium.error.NamespaceNotFound: Namespace horcrux_env not found. Have you installed the proper package for horcrux_env?
#
# The above exception was the direct cause of the following exception:
#
# ray::SingleAgentEnvRunner.__init__() (pid=62431, ip=10.254.233.114, actor_id=bd38b64249b89410b40ab2fc01000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x766dd2ae3910>)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 103, in __init__
#     self.make_env()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 707, in make_env
#     raise EnvError(
# ray.rllib.utils.error.EnvError: The env string you provided ('horcrux_env/plane-v0') is:
# a) Not a supported or an installed environment.
# b) Not a tune-registered environment creator.
# c) Not a valid env class string.
#
# Try one of the following:
# a) For Atari support: `pip install gymnasium[atari]` and prefix the environment name with `ale_py:`, for example, `"ale_py:ALE/Pong-v5"`.
# b) To register your custom env, do `from ray import tune; tune.register_env('[name]', lambda cfg: [return env obj from here using cfg])`.
#    Then in your config, do `config.environment(env='[name]').
# c) Make sure you provide a fully qualified classpath, e.g.:
#    `ray.rllib.examples.envs.classes.repeat_after_me_env.RepeatAfterMeEnv`
# 2026-01-28 21:56:50,571	ERROR env_runner_group.py:791 -- Validation of EnvRunner failed! Error=The actor died because of an error raised in its creation task, ray::SingleAgentEnvRunner.__init__() (pid=62436, ip=10.254.233.114, actor_id=76e0b793ce26d3f3bcb30cd501000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x7e7c579a48d0>)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 872, in make_vec
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 533, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 399, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 362, in _check_name_exists
#     _check_namespace_exists(ns)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 356, in _check_namespace_exists
#     raise error.NamespaceNotFound(f"Namespace {ns} not found. {suggestion_msg}")
# gymnasium.error.NamespaceNotFound: Namespace horcrux_env not found. Have you installed the proper package for horcrux_env?
#
# The above exception was the direct cause of the following exception:
#
# ray::SingleAgentEnvRunner.__init__() (pid=62436, ip=10.254.233.114, actor_id=76e0b793ce26d3f3bcb30cd501000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x7e7c579a48d0>)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 103, in __init__
#     self.make_env()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 707, in make_env
#     raise EnvError(
# ray.rllib.utils.error.EnvError: The env string you provided ('horcrux_env/plane-v0') is:
# a) Not a supported or an installed environment.
# b) Not a tune-registered environment creator.
# c) Not a valid env class string.
#
# Try one of the following:
# a) For Atari support: `pip install gymnasium[atari]` and prefix the environment name with `ale_py:`, for example, `"ale_py:ALE/Pong-v5"`.
# b) To register your custom env, do `from ray import tune; tune.register_env('[name]', lambda cfg: [return env obj from here using cfg])`.
#    Then in your config, do `config.environment(env='[name]').
# c) Make sure you provide a fully qualified classpath, e.g.:
#    `ray.rllib.examples.envs.classes.repeat_after_me_env.RepeatAfterMeEnv`
# 2026-01-28 21:56:50,571	ERROR env_runner_group.py:791 -- Validation of EnvRunner failed! Error=The actor died because of an error raised in its creation task, ray::SingleAgentEnvRunner.__init__() (pid=62444, ip=10.254.233.114, actor_id=a84c07a70b3a0e0e13f33ef301000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x777132f5c8d0>)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 872, in make_vec
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 533, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 399, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 362, in _check_name_exists
#     _check_namespace_exists(ns)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 356, in _check_namespace_exists
#     raise error.NamespaceNotFound(f"Namespace {ns} not found. {suggestion_msg}")
# gymnasium.error.NamespaceNotFound: Namespace horcrux_env not found. Have you installed the proper package for horcrux_env?
#
# The above exception was the direct cause of the following exception:
#
# ray::SingleAgentEnvRunner.__init__() (pid=62444, ip=10.254.233.114, actor_id=a84c07a70b3a0e0e13f33ef301000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x777132f5c8d0>)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 103, in __init__
#     self.make_env()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 707, in make_env
#     raise EnvError(
# ray.rllib.utils.error.EnvError: The env string you provided ('horcrux_env/plane-v0') is:
# a) Not a supported or an installed environment.
# b) Not a tune-registered environment creator.
# c) Not a valid env class string.
#
# Try one of the following:
# a) For Atari support: `pip install gymnasium[atari]` and prefix the environment name with `ale_py:`, for example, `"ale_py:ALE/Pong-v5"`.
# b) To register your custom env, do `from ray import tune; tune.register_env('[name]', lambda cfg: [return env obj from here using cfg])`.
#    Then in your config, do `config.environment(env='[name]').
# c) Make sure you provide a fully qualified classpath, e.g.:
#    `ray.rllib.examples.envs.classes.repeat_after_me_env.RepeatAfterMeEnv`
# 2026-01-28 21:56:50,571	ERROR env_runner_group.py:791 -- Validation of EnvRunner failed! Error=The actor died because of an error raised in its creation task, ray::SingleAgentEnvRunner.__init__() (pid=62448, ip=10.254.233.114, actor_id=8cab7ac8a7012a93c74017bc01000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x74a803f1fd50>)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 872, in make_vec
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 533, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 399, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 362, in _check_name_exists
#     _check_namespace_exists(ns)
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 356, in _check_namespace_exists
#     raise error.NamespaceNotFound(f"Namespace {ns} not found. {suggestion_msg}")
# gymnasium.error.NamespaceNotFound: Namespace horcrux_env not found. Have you installed the proper package for horcrux_env?
#
# The above exception was the direct cause of the following exception:
#
# ray::SingleAgentEnvRunner.__init__() (pid=62448, ip=10.254.233.114, actor_id=8cab7ac8a7012a93c74017bc01000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x74a803f1fd50>)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 103, in __init__
#     self.make_env()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bong/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 707, in make_env
#     raise EnvError(
# ray.rllib.utils.error.EnvError: The env string you provided ('horcrux_env/plane-v0') is:
# a) Not a supported or an installed environment.
# b) Not a tune-registered environment creator.
# c) Not a valid env class string.
#
# Try one of the following:
# a) For Atari support: `pip install gymnasium[atari]` and prefix the environment name with `ale_py:`, for example, `"ale_py:ALE/Pong-v5"`.
# b) To register your custom env, do `from ray import tune; tune.register_env('[name]', lambda cfg: [return env obj from here using cfg])`.
#    Then in your config, do `config.environment(env='[name]').
# c) Make sure you provide a fully qualified classpath, e.g.:
#    `ray.rllib.examples.envs.classes.repeat_after_me_env.RepeatAfterMeEnv`
# (SingleAgentEnvRunner pid=62431)
# (SingleAgentEnvRunner pid=62431)
# (SingleAgentEnvRunner pid=62431)
# (SingleAgentEnvRunner pid=62444)
# (SingleAgentEnvRunner pid=62444)
# (SingleAgentEnvRunner pid=62444)
# (SingleAgentEnvRunner pid=62448)
# (SingleAgentEnvRunner pid=62448)
# (SingleAgentEnvRunner pid=62448)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 # 알고리즘 인스턴스 생성
# ----> 2 algo = config.build_algo()
#       4 print("알고리즘 인스턴스 생성 완료")
#
# File ~/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/algorithms/algorithm_config.py:1006, in AlgorithmConfig.build_algo(self, env, logger_creator, use_copy)
#    1003 if isinstance(self.algo_class, str):
#    1004     algo_class = get_trainable_cls(self.algo_class)
# -> 1006 return algo_class(
#    1007     config=self if not use_copy else copy.deepcopy(self),
#    1008     logger_creator=self.logger_creator,
#    1009 )
#
# File ~/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/algorithms/sac/sac.py:574, in SAC.__init__(self, *args, **kwargs)
#     572 def __init__(self, *args, **kwargs):
#     573     self._allow_unknown_subkeys += ["policy_model_config", "q_model_config"]
# --> 574     super().__init__(*args, **kwargs)
#
# File ~/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/algorithms/algorithm.py:579, in Algorithm.__init__(self, config, env, logger_creator, **kwargs)
#     576 self._metrics_impala_training_step_zero_input_batches: Optional[Counter] = None
#     577 self._metrics_impala_training_step_env_steps_dropped: Optional[Counter] = None
# --> 579 super().__init__(
#     580     config=config,
#     581     logger_creator=logger_creator,
#     582     **kwargs,
#     583 )
#
# File ~/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/tune/trainable/trainable.py:158, in Trainable.__init__(self, config, logger_creator, storage)
#     154     logger.debug(f"StorageContext on the TRAINABLE:\n{storage}")
#     156 self._open_logfiles(stdout_file, stderr_file)
# --> 158 self.setup(copy.deepcopy(self.config))
#     159 setup_time = time.time() - self._start_time
#     160 if setup_time > SETUP_TIME_THRESHOLD:
#
# File ~/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/algorithms/dqn/dqn.py:613, in DQN.setup(self, config)
#     611 @override(Algorithm)
#     612 def setup(self, config: AlgorithmConfig) -> None:
# --> 613     super().setup(config)
#     615     if self.config.enable_env_runner_and_connector_v2 and self.env_runner_group:
#     616         if self.env_runner is None:
#
# File ~/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/algorithms/algorithm.py:825, in Algorithm.setup(self, config)
#     821     self.offline_data = None
#     823 if self.config.is_online or not self.config.enable_env_runner_and_connector_v2:
#     824     # Create a set of env runner actors via a EnvRunnerGroup.
# --> 825     self.env_runner_group = EnvRunnerGroup(
#     826         env_creator=self.env_creator,
#     827         validate_env=self.validate_env,
#     828         default_policy_class=self.get_default_policy_class(self.config),
#     829         config=self.config,
#     830         # New API stack: User decides whether to create local env runner.
#     831         # Old API stack: Always create local EnvRunner.
#     832         local_env_runner=(
#     833             True
#     834             if not self.config.enable_env_runner_and_connector_v2
#     835             else self.config.create_local_env_runner
#     836         ),
#     837         logdir=self.logdir,
#     838         tune_trial_id=self.trial_id,
#     839     )
#     841 # Compile, validate, and freeze an evaluation config.
#     842 self.evaluation_config = self.config.get_evaluation_config_object()
#
# File ~/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/env_runner_group.py:197, in EnvRunnerGroup.__init__(self, env_creator, validate_env, default_policy_class, config, local_env_runner, logdir, _setup, tune_trial_id, pg_offset, num_env_runners, num_workers, local_worker)
#     195 if _setup:
#     196     try:
# --> 197         self._setup(
#     198             validate_env=validate_env,
#     199             config=config,
#     200             num_env_runners=(
#     201                 num_env_runners
#     202                 if num_env_runners is not None
#     203                 else config.num_env_runners
#     204             ),
#     205             local_env_runner=local_env_runner,
#     206         )
#     207     # EnvRunnerGroup creation possibly fails, if some (remote) workers cannot
#     208     # be initialized properly (due to some errors in the EnvRunners's
#     209     # constructor).
#     210     except RayActorError as e:
#     211         # In case of an actor (remote worker) init failure, the remote worker
#     212         # may still exist and will be accessible, however, e.g. calling
#     213         # its `sample.remote()` would result in strange "property not found"
#     214         # errors.
#
# File ~/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/env_runner_group.py:285, in EnvRunnerGroup._setup(self, validate_env, config, num_env_runners, local_env_runner)
#     276 # If num_env_runners > 0 and we don't have an env on the local worker,
#     277 # get the observation- and action spaces for each policy from
#     278 # the first remote worker (which does have an env).
#     279 if (
#     280     local_env_runner
#     281     and self._worker_manager.num_actors() > 0
#     282     and not config.create_env_on_local_worker
#     283     and (not config.observation_space or not config.action_space)
#     284 ):
# --> 285     spaces = self.get_spaces()
#     286 else:
#     287     spaces = None
#
# File ~/anaconda3/envs/gd311/lib/python3.11/site-packages/ray/rllib/env/env_runner_group.py:313, in EnvRunnerGroup.get_spaces(self)
#     306 # Get ID of the first remote worker.
#     307 remote_worker_ids = (
#     308     [self._worker_manager.actor_ids()[0]]
#     309     if self._worker_manager.actor_ids()
#     310     else []
#     311 )
# --> 313 spaces = self.foreach_env_runner(
#     314     lambda env_runner: env_runner.get_spaces(),
#     315     remote_worker_ids=remote_worker_ids,
#     316     local_env_runner=not remote_worker_ids,
#     317 )[0]
#     319 logger.info(
#     320     "Inferred observation/action spaces from remote "
#     321     f"worker (local worker has no env): {spaces}"
#     322 )
#     324 return spaces
#
# IndexError: list index out of range
# (pid=gcs_server) [2026-01-28 21:57:07,231 E 62162 62162] (gcs_server) gcs_server.cc:303: Failed to establish connection to the event+metrics exporter agent. Events and metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (raylet) [2026-01-28 21:57:08,084 E 62332 62332] (raylet) main.cc:1032: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (pid=62454) [2026-01-28 21:57:09,297 E 62454 63462] core_worker_process.cc:842: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# [2026-01-28 21:57:09,564 E 61940 62426] core_worker_process.cc:842: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14

# %%
# 학습 실행
NUM_ITERATIONS = 10000  # 학습 반복 횟수

import pprint

for i in range(NUM_ITERATIONS):
    result = algo.train()
    
    if (i + 1) % 150 == 0:
        print(f"Iteration {i + 1}")
        print(algo.save(algo.logdir))

print(algo.save(algo.logdir))
print("학습 완료")

# %% [markdown]
# # 5. 학습 결과 평가

# %%
from ray.rllib.connectors.env_to_module import EnvToModulePipeline
from ray.rllib.connectors.module_to_env import ModuleToEnvPipeline

# 학습된 정책으로 평가 (새 API 스택 사용)
NUM_EVAL_EPISODES = 10
eval_results = []

# RLModule과 Connector 파이프라인 가져오기
rl_module = algo.get_module()

# EnvToModule과 ModuleToEnv 파이프라인 가져오기
# algo 객체에서 직접 가져올 수 있는 경우
try:
    # env_runner에서 connector 가져오기
    env_runner = algo.env_runner
    env_to_module = env_runner._connectors[0] if hasattr(env_runner, '_connectors') else None
    module_to_env = env_runner._connectors[1] if hasattr(env_runner, '_connectors') and len(env_runner._connectors) > 1 else None
except:
    env_to_module = None
    module_to_env = None

# 파이프라인을 직접 생성해야 하는 경우
if env_to_module is None or module_to_env is None:
    # 간단한 방법: RLModule만 사용하고 직접 처리
    from ray.rllib.core.columns import Columns
    
    env = gym.make(ENV_NAME, render_mode=None)
    device = getattr(rl_module, "device", next(rl_module.parameters()).device)
    
    for episode in range(NUM_EVAL_EPISODES):
        obs, info = env.reset()
        episode_reward = 0
        episode_length = 0
        done = False
        
        # Episode 객체 생성
        episode_obj = SingleAgentEpisode(
            observations=[obs],
            observation_space=env.observation_space,
            action_space=env.action_space,
        )
        
        # Option 1
        while not done:
            # 관찰을 텐서로 변환
            obs_batch = np.expand_dims(obs, 0).astype(np.float32)
            obs_tensor = torch.from_numpy(obs_batch).to(device)
            
            # forward_inference 사용 (평가 시에는 탐색 없음)
            rl_module_out = rl_module.forward_inference({"obs": obs_tensor})
            
            # ModuleToEnv 파이프라인이 없으므로 직접 처리
            # action_dist_inputs에서 액션 추출
            if Columns.ACTION_DIST_INPUTS in rl_module_out:
                action_dist_inputs = rl_module_out[Columns.ACTION_DIST_INPUTS]
            elif "action_dist_inputs" in rl_module_out:
                action_dist_inputs = rl_module_out["action_dist_inputs"]
            else:
                # 다른 키 확인
                action_dist_inputs = list(rl_module_out.values())[0]
            
            # action_dist_inputs 처리 (mean만 사용하거나 분포에서 샘플링)
            if isinstance(action_dist_inputs, torch.Tensor):
                dist_params = action_dist_inputs[0] if len(action_dist_inputs.shape) > 1 else action_dist_inputs
                
                if len(dist_params.shape) == 0 or dist_params.shape[0] == 14:
                    # mean만 있는 경우 (deterministic)
                    action_tensor = dist_params[:14] if len(dist_params) >= 14 else dist_params
                elif dist_params.shape[0] == 28:
                    # mean(14) + log_std(14) 구조
                    mean = dist_params[:14]
                    log_std = dist_params[14:]
                    std = torch.exp(log_std.clamp(-20, 2))
                    from torch.distributions import Normal
                    normal_dist = Normal(mean, std)
                    action_tensor = normal_dist.sample()
                else:
                    action_tensor = dist_params
                
                # 액션 공간에 맞게 클리핑
                action_low = torch.tensor(env.action_space.low, device=device, dtype=action_tensor.dtype)
                action_high = torch.tensor(env.action_space.high, device=device, dtype=action_tensor.dtype)
                
                
                bounded_action = torch.tanh(action_tensor[:14])
                # print(f'over:{(bounded_action[0:14] > 1).sum()}, below:{(bounded_action[0:14] < -1).sum()}, total:{(bounded_action[0:14] > 1).sum() + (bounded_action[0:14] < -1).sum()}')
                
                real_action = action_low + (0.5 * (bounded_action + 1.0) * (action_high - action_low))
                # print(real_action)

                action = real_action.detach().cpu().numpy()
            else:
                action = np.array(action_dist_inputs)
                if len(action.shape) > 1:
                    action = action[0]
                action = np.clip(action, env.action_space.low, env.action_space.high)
            
            obs, reward, terminated, truncated, info = env.step(action)
            done = terminated or truncated
            episode_reward += reward
            episode_length += 1
            
            if episode_length > 6000:
                done = True

            # Episode 업데이트
            episode_obj.add_env_step(
                obs,
                action,
                reward,
                terminated=terminated,
                truncated=truncated,
            )
        
        # Option 2
        # while not done:
        #     input_dict = env_to_module(
        #         episodes=[episode_obj],
        #         rl_module=rl_module,
        #         explore=False,
        #         shared_data={},
        #     )

        #     rl_module_out = rl_module.forward_inference(input_dict)

        #     to_env = module_to_env(
        #         batch=rl_module_out,
        #         episodes=[episode_obj],
        #         rl_module=rl_module,
        #         explore=False,
        #         shared_data={},
        #     )

        #     action = to_env.pop(Columns.ACTIONS)[0]
            
        #     obs, reward, terminated, truncated, info = env.step(action)
        #     done = terminated or truncated
        #     episode_reward += reward
        #     episode_length += 1
            
        #     # Episode 업데이트
        #     episode_obj.add_env_step(
        #         obs,
        #         action,
        #         reward,
        #         terminated=terminated,
        #         truncated=truncated,
        #     )
            

        print(episode_obj.get_return())
        eval_results.append({
            'episode': episode + 1,
            'reward': episode_reward,
            'length': episode_length,
        })
        
        if episode_obj.is_done:
            obs, info = env.reset()
            episode_obj = SingleAgentEpisode(
                observations=[obs],
                observation_space=env.observation_space,
                action_space=env.action_space,
            )
    
    env.close()
else:
    # 파이프라인이 있는 경우 예제 방식 사용
    env = gym.make(ENV_NAME, render_mode=None)
    
    obs, _ = env.reset()
    episode_obj = SingleAgentEpisode(
        observations=[obs],
        observation_space=env.observation_space,
        action_space=env.action_space,
    )
    
    num_episodes = 0
    while num_episodes < NUM_EVAL_EPISODES:
        shared_data = {}
        input_dict = env_to_module(
            episodes=[episode_obj],
            rl_module=rl_module,
            explore=False,
            shared_data=shared_data,
        )
        
        rl_module_out = rl_module.forward_inference(input_dict)
        
        to_env = module_to_env(
            batch=rl_module_out,
            episodes=[episode_obj],
            rl_module=rl_module,
            explore=False,
            shared_data=shared_data,
        )
        
        action = to_env.pop(Columns.ACTIONS)[0]
        obs, reward, terminated, truncated, _ = env.step(action)
        
        episode_obj.add_env_step(
            obs,
            action,
            reward,
            terminated=terminated,
            truncated=truncated,
            extra_model_outputs={k: v[0] for k, v in to_env.items()},
        )
        
        if episode_obj.is_done:
            eval_results.append({
                'episode': num_episodes + 1,
                'reward': episode_obj.get_return(),
                'length': len(episode_obj),
            })
            obs, info = env.reset()
            episode_obj = SingleAgentEpisode(
                observations=[obs],
                observation_space=env.observation_space,
                action_space=env.action_space,
            )
            num_episodes += 1
    
    env.close()


eval_df = pd.DataFrame(eval_results)
print("\n평가 결과:")
print(eval_df)
print(f"\n평균 보상: {eval_df['reward'].mean():.2f} ± {eval_df['reward'].std():.2f}")
print(f"평균 에피소드 길이: {eval_df['length'].mean():.2f} ± {eval_df['length'].std():.2f}")

# # 평가 결과 저장
# eval_df.to_csv(RESULTS_DIR / "evaluation_results.csv", index=False)

# %% [markdown]
# ## 7. 모델 저장 및 로드

# %%
algo.save(algo.logdir)

# %%
# 모델 저장
checkpoint_dir = algo.save()
print(f"모델 저장 완료: {checkpoint_dir}")

# 모델 로드 예시 (주석 처리)
# loaded_algo = Algorithm.from_checkpoint(checkpoint_dir)

# %% [markdown]
# ## 8. 정리

# %%
# 알고리즘 정리
algo.stop()

# Ray 종료 (필요한 경우)
# ray.shutdown()

print("정리 완료")
